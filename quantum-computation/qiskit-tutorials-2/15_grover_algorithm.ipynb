# %%
from qiskit import *
from qiskit.tools.visualization import plot_histogram, plot_bloch_multivector
# %matplotlib inline

# %%
# Grover algorithm for state |00>

circuit = QuantumCircuit(2, 2)

circuit.h(0)
circuit.h(1)

circuit.barrier()

circuit.x(0)
circuit.x(1)

circuit.cz(0,1)

circuit.x(0)
circuit.x(1)

circuit.h(0)
circuit.h(1)

circuit.barrier()

circuit.z(0)
circuit.z(1)

circuit.cz(0,1)

circuit.barrier()

circuit.h(0)
circuit.h(1)

circuit.measure([0,1],[0,1])

circuit.draw(output="mpl")

# %%
simulator = Aer.get_backend("qasm_simulator")
result = execute(circuit, backend=simulator, shots= 1024).result()

counts = result.get_counts()

plot_histogram(counts)

# %%
statevec_sim = qiskit.Aer.get_backend("statevector_simulator")
sim_state_vector = qiskit.execute(circuit, backend=statevec_sim).result().get_statevector()
plot_bloch_multivector(sim_state_vector)

# %%
# Grover algorithm for state |01>

circuit = QuantumCircuit(2, 2)

circuit.h(0)
circuit.h(1)

circuit.s(1)
circuit.h(1)

circuit.barrier()

circuit.cx(0,1)

circuit.h(0)
circuit.h(1)

circuit.x(0)
circuit.s(1)
circuit.h(1)
circuit.x(1)
circuit.h(1)

circuit.cx(0,1)

circuit.barrier()

circuit.x(0)
circuit.h(1)

circuit.h(0)
circuit.x(1)

circuit.measure(0,0)

circuit.h(1)

circuit.measure(1,1)

circuit.draw(output="mpl")

# %%
simulator = Aer.get_backend("qasm_simulator")
result = execute(circuit, backend=simulator, shots= 1024).result()

counts = result.get_counts()

plot_histogram(counts)

# %%
statevec_sim = qiskit.Aer.get_backend("statevector_simulator")
sim_state_vector = qiskit.execute(circuit, backend=statevec_sim).result().get_statevector()
plot_bloch_multivector(sim_state_vector)

# %%
# Grover algorithm for state |10>

circuit = QuantumCircuit(2, 2)

circuit.h(0)
circuit.h(1)

circuit.s(0)
circuit.h(1)

circuit.barrier()

circuit.cx(0,1)

circuit.s(0)
circuit.h(1)

circuit.h(0)
circuit.h(1)

circuit.x(0)
circuit.x(1)

circuit.h(1)
circuit.cx(0,1)

circuit.barrier()

circuit.x(0)
circuit.h(1)
circuit.h(0)
circuit.x(1)

circuit.cx(0,1)

circuit.measure(0,0)

circuit.h(1)

circuit.measure(1,1)

circuit.draw(output="mpl")

# %%
simulator = Aer.get_backend("qasm_simulator")
result = execute(circuit, backend=simulator, shots= 1024).result()

counts = result.get_counts()

plot_histogram(counts)

# %%
statevec_sim = qiskit.Aer.get_backend("statevector_simulator")
sim_state_vector = qiskit.execute(circuit, backend=statevec_sim).result().get_statevector()
plot_bloch_multivector(sim_state_vector)

# %%
# Grover algorithm for state |11>

circuit = QuantumCircuit(2, 2)

circuit.h(0)
circuit.h(1)
circuit.h(1)

circuit.barrier()

circuit.cx(0,1)

circuit.h(0)
circuit.h(1)

circuit.x(0)
circuit.h(1)

circuit.x(1)
circuit.h(1)

circuit.cx(0,1)

circuit.barrier()

circuit.x(0)
circuit.h(1)
circuit.h(0)
circuit.x(1)

circuit.measure(0,0)

circuit.h(1)

circuit.measure(1,1)

circuit.draw(output="mpl")

# %%
simulator = Aer.get_backend("qasm_simulator")
result = execute(circuit, backend=simulator, shots= 1024).result()

counts = result.get_counts()

plot_histogram(counts)

# %%
statevec_sim = qiskit.Aer.get_backend("statevector_simulator")
sim_state_vector = qiskit.execute(circuit, backend=statevec_sim).result().get_statevector()
plot_bloch_multivector(sim_state_vector)

# %%
# Grover algorithm for state |11>

circuit = QuantumCircuit(2, 2)

circuit.h(0)
circuit.h(1)
circuit.h(1)

circuit.barrier()

circuit.cx(0,1)
circuit.h(0)
circuit.h(1)
circuit.h(1)

circuit.x(0)
circuit.h(0)
circuit.x(1)
circuit.cx(1,0)

circuit.barrier()

circuit.h(0)
circuit.x(1)
circuit.x(0)
circuit.h(0)
circuit.h(1)

circuit.measure([0,1],[0,1])

circuit.draw(output="mpl")

# %%
simulator = Aer.get_backend("qasm_simulator")
result = execute(circuit, backend=simulator, shots= 1024).result()

counts = result.get_counts()

plot_histogram(counts)

# %%
statevec_sim = qiskit.Aer.get_backend("statevector_simulator")
sim_state_vector = qiskit.execute(circuit, backend=statevec_sim).result().get_statevector()
plot_bloch_multivector(sim_state_vector)

# %%
import qiskit
qiskit.__qiskit_version__
# Out:
# {'qiskit-terra': '0.13.0',
#  'qiskit-aer': '0.5.0',
#  'qiskit-ignis': '0.3.0',
#  'qiskit-ibmq-provider': '0.6.0',
#  'qiskit-aqua': '0.6.5',
#  'qiskit': '0.18.0'}
