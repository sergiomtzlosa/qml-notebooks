# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, Aer, execute
from qiskit.quantum_info import Statevector
import quantum_imaging as qi
import quantum_drawer as qd
from IPython.display import Image
import numpy as np
# %matplotlib inline

# %%
image_doge = qi.convert_to_bw("doge.png") # WoW ! *Much* quantum! *very* doge!
qi.image_from_array(image_doge)
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7F3D5646A760>

# %%
resized_image_doge = qi.resize_array(image_doge, size=(64, 64))
qi.image_from_array(resized_image_doge)
# Out:
# <PIL.Image.Image image mode=L size=64x64 at 0x7F3D10BEF790>

# %%
array_binary_doge = qi.binary_encode(resized_image_doge)
qi.save_bin_array_to_csv('doge.csv', array_binary_doge)

# %%
image_qiskit = qi.convert_to_bw("logo.jpg")
qi.image_from_array(image_qiskit)
# Out:
# <PIL.Image.Image image mode=L size=410x410 at 0x7FB6612B4580>

# %%
resized_image_qiskit = qi.resize_array(image_qiskit, size=(64, 64))
qi.image_from_array(resized_image_qiskit)
# Out:
# <PIL.Image.Image image mode=L size=64x64 at 0x7FB6612B4460>

# %%
array_binary_qiskit = qi.binary_encode(resized_image_qiskit)
qi.save_bin_array_to_csv('qiskit_logo.csv', array_binary_qiskit)

# %%
resized_image_qiskit_tiny = qi.resize_array(image_qiskit, size=(32, 32))
qi.image_from_array(resized_image_qiskit_tiny)
# Out:
# <PIL.Image.Image image mode=L size=32x32 at 0x7FB6612B49D0>

# %%
array_binary_qiskit_tiny = qi.binary_encode(resized_image_qiskit_tiny)
qi.save_bin_array_to_csv('qiskit_logo_tiny.csv', array_binary_qiskit_tiny)

# %%
Image('quantum-fistro.png')

# %%
image_fistro = qi.convert_to_bw("quantum-fistro.png")
qi.image_from_array(image_fistro)
# Out:
# <PIL.Image.Image image mode=L size=346x346 at 0x13C98547760>

# %%
resized_image_fistro = qi.resize_array(image_fistro, size=(128, 128))
qi.image_from_array(resized_image_fistro)
# Out:
# <PIL.Image.Image image mode=L size=128x128 at 0x13C9C934820>

# %%
array_binary_fistro = qi.binary_encode(resized_image_fistro)
qi.save_bin_array_to_csv('quantum_fistro.csv', array_binary_fistro)

# %%
resized_image_fistro_little = qi.resize_array(image_fistro, size=(32, 32))
qi.image_from_array(resized_image_fistro_little)
# Out:
# <PIL.Image.Image image mode=L size=32x32 at 0x13C9C9345E0>

# %%
array_binary_fistro_little = qi.binary_encode(resized_image_fistro_little)
qi.save_bin_array_to_csv('quantum_fistro_little.csv', array_binary_fistro_little)

# %%
image = qi.convert_to_bw("mario.jpg")
qi.image_from_array(image)
# Out:
# <PIL.Image.Image image mode=L size=236x295 at 0x7F3D10BEF370>

# %%
image.shape
# Out:
# (295, 236)

# %%
resized_image = qi.resize_array(image, size=(64, 64))
qi.image_from_array(resized_image)
# Out:
# <PIL.Image.Image image mode=L size=64x64 at 0x7F3D10B9F070>

# %%
array_binary = qi.binary_encode(resized_image)
qi.save_bin_array_to_csv('mario.csv', array_binary)

# %%
resized_image = qi.resize_array(image, size=(32, 32))
qi.image_from_array(resized_image)
# Out:
# <PIL.Image.Image image mode=L size=32x32 at 0x7F3C7D593DC0>

# %%
array_binary = qi.binary_encode(resized_image)
qi.save_bin_array_to_csv('mario_tiny.csv', array_binary)

# %%
Image('quantum-risitas.png')

# %%
image_risitas = qi.convert_to_bw("quantum-risitas.png")
qi.image_from_array(image_risitas)
# Out:
# <PIL.Image.Image image mode=L size=381x382 at 0x7F3D10B988E0>

# %%
image_risitas.shape
# Out:
# (382, 381)

# %%
resized_image_risitas = qi.resize_array(image_risitas, size=(128, 128))
qi.image_from_array(resized_image_risitas)
# Out:
# <PIL.Image.Image image mode=L size=128x128 at 0x7F3D10BAB550>

# %%
array_binary_risitas = qi.binary_encode(resized_image_risitas)
qi.save_bin_array_to_csv('quantum_risitas.csv', array_binary_risitas)

# %% [markdown]
# # Use one-hot encoding drawing file to create a Quantum circuit and rebuild the image with the circuit result

# %% [markdown]
# # Only support square images (i.e: 32x32px, 64x64px)

# %%
# Simulator
qasm_sim = Aer.get_backend("aer_simulator")

# Number of circuit qubits
n_qubits = 7

# %%
binary_data_array = qi.load_bin_array_from_csv('quantum_fistro.csv')

cols_items = binary_data_array.shape[1]
splitting = qd.splitting_chunks(cols_items, n_qubits)

rework_image = qd.rebuild_image_quantum(binary_data_array, splitting, n_qubits, qasm_sim)
rework_image.shape
# Out:
# (128, 128)

# %%
rebuild_data = qi.rebuild_binary_array(rework_image)
#qi.image_from_array(rebuild_data)
scaled_image = qi.scale_binary_image(rebuild_data, 5)
qi.image_from_array(scaled_image)
# Out:
# <PIL.Image.Image image mode=L size=640x640 at 0x138012174F0>

# %%
qi.save_image_file('quantum_fistro.jpg', scaled_image)

# %%
binary_data_array = qi.load_bin_array_from_csv('qiskit_logo.csv')

cols_items = binary_data_array.shape[1]
splitting = qd.splitting_chunks(cols_items, n_qubits)

rework_image = qd.rebuild_image_quantum_enhance_onerun(binary_data_array, splitting, n_qubits, qasm_sim)
rework_image.shape
# Out:
# (64, 64)

# %%
rebuild_data = qi.rebuild_binary_array(rework_image)
#qi.image_from_array(rebuild_data)
scaled_image = qi.scale_binary_image(rebuild_data, 5)
qi.image_from_array(scaled_image)
# Out:
# <PIL.Image.Image image mode=L size=320x320 at 0x7F3CF5855E50>

# %%
binary_data_array = qi.load_bin_array_from_csv('mario.csv')

cols_items = binary_data_array.shape[1]
splitting = qd.splitting_chunks(cols_items, n_qubits)

rework_image = qd.rebuild_image_quantum_enhance_onerun(binary_data_array, splitting, n_qubits, qasm_sim)
rework_image.shape
# Out:
# (64, 64)

# %%
rebuild_data = qi.rebuild_binary_array(rework_image)
#qi.image_from_array(rebuild_data)
scaled_image = qi.scale_binary_image(rebuild_data, 5)
qi.image_from_array(scaled_image)
# Out:
# <PIL.Image.Image image mode=L size=320x320 at 0x7F3D10B98F10>

# %%
binary_data_array = qi.load_bin_array_from_csv('doge.csv')

cols_items = binary_data_array.shape[1]
splitting = qd.splitting_chunks(cols_items, n_qubits)

rework_image = qd.rebuild_image_quantum_enhance_onerun(binary_data_array, splitting, n_qubits, qasm_sim)
rework_image.shape
# Out:
# (64, 64)

# %%
rebuild_data = qi.rebuild_binary_array(rework_image)
#qi.image_from_array(rebuild_data)
scaled_image = qi.scale_binary_image(rebuild_data, 5)
qi.image_from_array(scaled_image)
# Out:
# <PIL.Image.Image image mode=L size=320x320 at 0x7F3CFE0A6B20>

# %%
binary_data_array = qi.load_bin_array_from_csv('quantum_risitas.csv')

cols_items = binary_data_array.shape[1]
splitting = qd.splitting_chunks(cols_items, n_qubits)

rework_image = qd.rebuild_image_quantum_enhance_onerun(binary_data_array, splitting, n_qubits, qasm_sim)
rework_image.shape
# Out:
# (128, 128)

# %%
rebuild_data = qi.rebuild_binary_array(rework_image)
#qi.image_from_array(rebuild_data)
scaled_image = qi.scale_binary_image(rebuild_data, 5)
qi.image_from_array(scaled_image)
# Out:
# <PIL.Image.Image image mode=L size=640x640 at 0x7F3CF4DD41C0>

# %% [markdown]
# # Sending circuit to real quantum computer - attemp 1

# %%
from qiskit import IBMQ
from qiskit.providers.ibmq import least_busy
import qiskit.tools.jupyter

# %%
if not IBMQ.active_account():
    IBMQ.load_account()

all_providers = IBMQ.providers()

provider = all_providers[1] #IBMQ.get_provider(hub='ibm-q', group='open', project='main')
provider

# %%
# %qiskit_backend_overview
# Out:
# VBox(children=(HTML(value="<h2 style ='color:#ffffff; background-color:#000000;padding-top: 1%; padding-bottom…

# %%
n_qubits = 10

# %%
backend = least_busy(provider.backends(filters=lambda b: b.configuration().n_qubits >= n_qubits and b.status().operational and not b.configuration().simulator))

# %%
backend

# %%
# %qiskit_job_watcher
# Out:
# Accordion(children=(VBox(layout=Layout(max_width='710px', min_width='710px')),), layout=Layout(max_height='500…

# %%
binary_data_array = qi.load_bin_array_from_csv('mario_tiny.csv')

cols_items = binary_data_array.shape[1]
splitting = qd.splitting_chunks(cols_items, n_qubits)

rework_image = qd.rebuild_image_quantum_enhance_onerun(binary_data_array, splitting, n_qubits, backend, num_shots = 1024)
rework_image.shape
# Out:
# (32, 32)

# %%
# %qiskit_disable_job_watcher

# %%
rebuild_data = qi.rebuild_binary_array(rework_image)
#qi.image_from_array(rebuild_data)
scaled_image = qi.scale_binary_image(rebuild_data, 10)
qi.image_from_array(scaled_image)
# Out:
# <PIL.Image.Image image mode=L size=320x320 at 0x7F07B5E72610>

# %%
inverted = np.invert(scaled_image)
qi.image_from_array(inverted)
# Out:
# <PIL.Image.Image image mode=L size=320x320 at 0x7F0781DA9580>

# %% [markdown]
# # Sending circuit to real quantum computer - attemp 2

# %%
from qiskit import IBMQ
from qiskit.providers.ibmq import least_busy
import qiskit.tools.jupyter

# %%
if not IBMQ.active_account():
    IBMQ.load_account()

all_providers = IBMQ.providers()

provider = all_providers[1] #IBMQ.get_provider(hub='ibm-q', group='open', project='main')
provider

# %%
n_qubits = 27

# %%
backend = least_busy(provider.backends(filters=lambda b: b.configuration().n_qubits >= n_qubits and b.status().operational and not b.configuration().simulator))

# %%
# %qiskit_backend_overview
# Out:
# VBox(children=(HTML(value="<h2 style ='color:#ffffff; background-color:#000000;padding-top: 1%; padding-bottom…

# %%
# %qiskit_job_watcher
# Out:
# Accordion(children=(VBox(layout=Layout(max_width='710px', min_width='710px')),), layout=Layout(max_height='500…

# %%
binary_data_array = qi.load_bin_array_from_csv('qiskit_logo_tiny.csv')

cols_items = binary_data_array.shape[1]
splitting = qd.splitting_chunks(cols_items, n_qubits)

rework_image = qd.rebuild_image_quantum_enhance_onerun(binary_data_array, splitting, n_qubits, backend, num_shots = 1024)
rework_image.shape

# %%
# %qiskit_disable_job_watcher

# %%
rebuild_data = qi.rebuild_binary_array(rework_image)
#qi.image_from_array(rebuild_data)
scaled_image = qi.scale_binary_image(rebuild_data, 5)
qi.image_from_array(scaled_image)

# %%
# %qiskit_version_table
# Out:
# <h3>Version Information</h3><table><tr><th>Qiskit Software</th><th>Version</th></tr><tr><td>Qiskit</td><td>0.26.2</td></tr><tr><td>Terra</td><td>0.17.4</td></tr><tr><td>Aer</td><td>0.8.2</td></tr><tr><td>Ignis</td><td>0.6.0</td></tr><tr><td>Aqua</td><td>0.9.1</td></tr><tr><td>IBM Q Provider</td><td>0.13.1</td></tr><tr><th>System information</th></tr><tr><td>Python</td><td>3.8.2 (default, Apr 23 2020, 14:22:33)
# [GCC 8.3.0]</td></tr><tr><td>OS</td><td>Linux</td></tr><tr><td>CPUs</td><td>4</td></tr><tr><td>Memory (Gb)</td><td>7.435432434082031</td></tr><tr><td colspan='2'>Mon Jun 21 14:14:24 2021 BST</td></tr></table>
